# %% [markdown]
# ### Handling the ZeroDivisionError Exception

# %%
print(5/0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15704\1152173066.py in <module>
# ----> 1 print(5/0)
#
# ZeroDivisionError: division by zero

# %%
# Using try-except Blocks
try:
    print(5/0)
except ZeroDivisionError:
    print('You can not divide by zero!')

# %%
# Any code that depends on the try block executing successfully goes in the else block

print("Give two numbers, I will devide them.")
print("Enter q to quit.")

while True:
    first_number = input("\nFirst Number: ")
    if first_number == 'q':
        break
    second_number = input("\nSecond Number: ")
    if second_number == 'q':
        break
    try:
        answer = int(first_number)/int(second_number)
    except ZeroDivisionError:
        print('You can not divide by zero!')
    else:
        print(answer)

# %% [markdown]
# ### Handling the FileNotFoundError Exception

# %%
filename = 'alice.txt'

with open(filename, encoding='utf-8') as file_content:
    contents = file_content.read()

print(contents)
