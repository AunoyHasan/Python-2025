# %% [markdown]
# ### Defining and printing a touple

# %%
dimentions = (4, 10, 16, 32)

print(dimentions)
# Out:
# (4, 10, 16, 32)

# %%
for dimention in dimentions:
    print(dimention)
# Out:
# 4
# 10
# 16
# 32

# %%
# writing over a touple
dimentions = (10, 20, 30, 40)
for dimention in dimentions:
    print(dimention)
# Out:
# 10
# 20
# 30
# 40
