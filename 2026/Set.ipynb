# %% [markdown]
# ### Defining a set

# %%
languages = {'python', 'ruby', 'c', 'java', 'c sharp'}

languages
# Out:
# {'c', 'c sharp', 'java', 'python', 'ruby'}

# %% [markdown]
# ### A list of dictionaries

# %%
alien_0 = {'color': 'green', 'points': 5}
alien_1 = {'color': 'yellow', 'points': 10}
alien_2 = {'color': 'red', 'points': 35}

alien = [alien_0, alien_1, alien_2]

print(alien)
# Out:
# [{'color': 'green', 'points': 5}, {'color': 'yellow', 'points': 10}, {'color': 'red', 'points': 35}]

# %% [markdown]
# ###  A list in a dictionary

# %%
favourite_languages = {
    'jen': ['python', 'ruby'],
    'sarah': ['c'],
    'edward': ['ruby', 'go'],
    'phil': ['python', 'haskell']
}

for name, languages in favourite_languages.items():
    print(f"\n{name.title()}'s favourite languages are: ")
    for language in languages:
        print(f"\t{language.title()}")
# Out:
# Jen's favourite languages are:
# 	Python
# 	Ruby
#
# Sarah's favourite languages are:
# 	C
#
# Edward's favourite languages are:
# 	Ruby
# 	Go
#
# Phil's favourite languages are:
# 	Python
# 	Haskell

# %% [markdown]
# ### A dictionary in a dictionary

# %%
users = {
    'aeinstein': {
        'first_name': 'albert',
        'last_name': 'einstein',
        'location': 'princeton'
    },
    
    'mcurie': {
        'first_name': 'marie',
        'last_name': 'curie',
        'location': 'paris'
    }
}

for username, user_info in users.items():
    print(f"\nUsername: {username}")
    full_name = f"{user_info['first_name']} {user_info['last_name']}"
    locaiton = user_info['location']
    
    print(f"\tFull name: {full_name.title()}")
    print(f"\tLocatin: {location.title()}")
# Out:
# Username: aeinstein
# 	Full name: Albert Einstein
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8576\3096669947.py in <module>
#      19
#      20     print(f"\tFull name: {full_name.title()}")
# ---> 21     print(f"\tLocatin: {location.title()}")
#
# NameError: name 'location' is not defined
