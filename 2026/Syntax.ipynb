# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
print('String Operations')
# Out:
# String Operations

# %%
# Multiple string
a = """ My name is Mahmudul Hasan Aunoy.
I am pursuing MSc in Computer Scince and Engineerng
I come from Bangladesh.
"""

a
# Out:
# ' My name is Mahmudul Hasan Aunoy.\nI am pursuing MSc in Computer Scince and Engineerng\nI come from Bangladesh.\n'

# %%
print(a)
# Out:
#  My name is Mahmudul Hasan Aunoy.
# I am pursuing MSc in Computer Scince and Engineerng
# I come from Bangladesh.

# %%
b = 'Computer Science and Engineering'
print(b[3])
# Out:
# p

# %%
b[3]
# Out:
# 'p'

# %%
# print through a loop
for x in b:
    print(x);
# Out:
# C
# o
# m
# p
# u
# t
# e
# r
#
# S
# c
# i
# e
# n
# c
# e
#
# a
# n
# d
#
# E
# n
# g
# i
# n
# e
# e
# r
# i
# n
# g

# %%
# Length
print(len(b))
# Out:
# 32

# %%
print("free" in b)
# Out:
# False

# %%
print("free" not in b)
# Out:
# True

# %%
if "txt" not in b:
    print("txt is not present in b")
# Out:
# txt is not present in b

# %%
name = "Mahmudul Hasan Aunoy"

print(name[2:5])
# Out:
# hmu

# %%
print(name[:5])
# Out:
# Mahmu

# %%
print(name[2:])
# Out:
# hmudul Hasan Aunoy

# %%
b = "Hello, World!"
print(b[-5:-2])
# Out:
# orl

# %%
# Modify String
print(name.upper())
print(name.lower())
print(name.strip())
# Out:
# MAHMUDUL HASAN AUNOY
# mahmudul hasan aunoy
# Mahmudul Hasan Aunoy

# %%
a = "Hello, World!"
print(a.replace("H", "J"))
# Out:
# Jello, World!

# %%
print(name.split(" "))
# Out:
# ['Mahmudul', 'Hasan', 'Aunoy']

# %%
# concat
concat = a + " " + name
print(concat)
# Out:
# Hello, World! Mahmudul Hasan Aunoy

# %%
# Fotmat String
age = 26
txt = f"My name is {name}, I am {age}"
print(txt)
# Out:
# My name is Mahmudul Hasan Aunoy, I am 26

# %%
price = 59
pri = f"Now I have {price}"
pri2 = f"The price is {price:.2f} dollars"
print(pri)
print(pri2)
# Out:
# Now I have 59
# The price is 59.00 dollars

# %%
# Escape characters
viking = "Vikings started from \"Norway\" and buildt Denmark"
print(viking)
# Out:
# Vikings started from "Norway" and buildt Denmark
